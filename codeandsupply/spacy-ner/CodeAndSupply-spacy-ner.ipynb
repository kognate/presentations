# %%
import spacy
from spacy import displacy
from collections import Counter

# %%
nlp = spacy.load('en')

# %%
from bs4 import  BeautifulSoup
import requests
import re

# %%
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, "html5lib")
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# %%
ny_bb = url_to_string('https://www.newyorker.com/culture/culture-desk/the-childlike-strangeness-of-melania-trumps-be-best-campaign')

# %%
article = nlp(ny_bb)

# %%
len(article.ents)
# Out:
# 126

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'ORG': 43,
#          'GPE': 21,
#          'PERSON': 22,
#          'DATE': 18,
#          'ORDINAL': 6,
#          'NORP': 3,
#          'CARDINAL': 6,
#          'MONEY': 1,
#          'FAC': 3,
#          'PRODUCT': 3})

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('Melania', 14), ('\xa0', 7), ('First', 5)]

# %%
sentences = [x for x in article.sents]
print(sentences[10])
# Out:
# the unveiling of her official agenda, on Monday, it was almost as if the First Lady, in speaking out on behalf of American kids, was really advocating for herself.

# %%
displacy.render(nlp(str(sentences[10])), jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5">the unveiling of her official agenda, on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , it was almost as if the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     First
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  Lady, in speaking out on behalf of
# ...

# %%
displacy.render(nlp(str(sentences[10])), jupyter=True, style='dep')
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="5125" height="1012.0" style="max-width: none; height: 1012.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">unveiling</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
# ...

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[10])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('unveiling', 'NOUN', 'unveiling'),
#  ('official', 'ADJ', 'official'),
#  ('agenda', 'NOUN', 'agenda'),
#  ('Monday', 'PROPN', 'monday'),
#  ('First', 'PROPN', 'first'),
#  ('Lady', 'PROPN', 'lady'),
#  ('speaking', 'VERB', 'speak'),
#  ('behalf', 'NOUN', 'behalf'),
#  ('American', 'ADJ', 'american'),
#  ('kids', 'NOUN', 'kid'),
#  ('advocating', 'VERB', 'advocate')]

# %%
dict([(x.lemma_, x.pos_) for x in [y
                    for y
                    in nlp('How much does a can of chicken soup cost?')
                    if not y.is_stop and y.pos_ != 'PUNCT']])
# Out:
# {'how': 'ADV', 'chicken': 'NOUN', 'soup': 'NOUN', 'cost': 'NOUN'}

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences[10])).ents])
# Out:
# {'Monday': 'DATE', 'First': 'ORDINAL', 'American': 'NORP'}

# %%
displacy.render(article, jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     The Childlike Strangeness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Melania
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Trump’s “Be Best” Campaign |
# ...
